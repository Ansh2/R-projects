# %% [markdown]
# # Project 03 -- Ansh Tandon

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
myDF <- read.csv("/anvil/projects/tdm/data/craigslist/vehicles.csv")

# %%
options(jupyter.rich_display = F)

# %%
head(myDF)
# Out:
#   id
# 1 7222695916
# 2 7218891961
# 3 7221797935
# 4 7222270760
# 5 7210384030
# 6 7222379453
#   url
# 1 https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html
# 2 https://fayar.craigslist.org/ctd/d/bentonville-2017-hyundai-elantra-se/7218891961.html
# 3 https://keys.craigslist.org/cto/d/summerland-key-2005-excursion/7221797935.html
# 4 https://worcester.craigslist.org/cto/d/west-brookfield-2002-honda-odyssey-ex/7222270760.html
# 5 https://greensboro.craigslist.org/cto/d/trinity-1965-chevrolet-truck/7210384030.html
# 6 https://hudsonvalley.craigslist.org/cto/d/westtown-2007-ford-150/7222379453.html
#   region                 region_url                          price year
# 1 prescott               https://prescott.craigslist.org      6000 NA
# 2 fayetteville           https://fayar.craigslist.org        11900 NA
# 3 florida keys           https://keys.craigslist.org         21000 NA
# 4 worcester / central MA https://worcester.craigslist.org     1500 NA
# ...

# %%
dim(myDF)
# Out:
# [1] 426880     26

# %%
str(myDF)
# Out:
# 'data.frame':	426880 obs. of  26 variables:
#  $ id          : num  7.22e+09 7.22e+09 7.22e+09 7.22e+09 7.21e+09 ...
#  $ url         : chr  "https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html" "https://fayar.craigslist.org/ctd/d/bentonville-2017-hyundai-elantra-se/7218891961.html" "https://keys.craigslist.org/cto/d/summerland-key-2005-excursion/7221797935.html" "https://worcester.craigslist.org/cto/d/west-brookfield-2002-honda-odyssey-ex/7222270760.html" ...
#  $ region      : chr  "prescott" "fayetteville" "florida keys" "worcester / central MA" ...
#  $ region_url  : chr  "https://prescott.craigslist.org" "https://fayar.craigslist.org" "https://keys.craigslist.org" "https://worcester.craigslist.org" ...
#  $ price       : num  6000 11900 21000 1500 4900 ...
#  $ year        : int  NA NA NA NA NA NA NA NA NA NA ...
#  $ manufacturer: chr  "" "" "" "" ...
#  $ model       : chr  "" "" "" "" ...
#  $ condition   : chr  "" "" "" "" ...
# ...

# %%
table(myDF$state)
# Out:
#    ak    al    ar    az    ca    co    ct    dc    de    fl    ga    hi    ia
#  3474  4955  4038  8679 50614 11088  5188  2970   949 28511  7003  2964  8632
#    id    il    in    ks    ky    la    ma    md    me    mi    mn    mo    ms
#  8961 10387  5704  6209  4149  3196  8174  4778  2966 16900  7716  4293  1016
#    mt    nc    nd    ne    nh    nj    nm    nv    ny    oh    ok    or    pa
#  6294 15277   410  1036  2981  9742  4425  3194 19386 17696  6792 17104 13753
#    ri    sc    sd    tn    tx    ut    va    vt    wa    wi    wv    wy
#  2320  6327  1302 11066 22945  1150 10732  2513 13861 11398  1052   610

# %% [markdown]
# There are 426880 rows and 26 columns in our dataframe.
#
# The types of data in this data include numerical values, character strings, integers, and logical values.
#
# Within this dataset, I see that there are various car manufacturers, from Acura to Mercedes-Benz, which indicates that this is some large data set of various vehicles on a website that are on sale. In addition, I see that the states with the most cars include California and Florida, as they obviously have a large population of individuals.

# %% [markdown]
# ## Question 2

# %%
table(myDF$year, useNA = "always")
# Out:
#  1900  1901  1902  1903  1905  1909  1910  1913  1915  1916  1918  1920  1921
#    12     3     1    12     1     1     2     2     1     2     1     2     2
#  1922  1923  1924  1925  1926  1927  1928  1929  1930  1931  1932  1933  1934
#     3    36     9     8    16    37    38    57    68    58    57    25    44
#  1935  1936  1937  1938  1939  1940  1941  1942  1943  1944  1945  1946  1947
#    23    43    70    38    54    81    67    15     1     3     2    58    71
#  1948  1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
#   100    89   106    98   110   105   100   226   160   174    73    93   120
#  1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973
#    82   138   234   270   365   424   357   425   409   345   312   409   334
#  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  1986
#   280   204   242   273   345   387   272   214   217   257   387   469   523
# ...

# %%
head(myDF$year, n = 20)
# Out:
#  [1] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA

# %%
head(is.na(myDF$year), n = 50)
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [25]  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [49] FALSE FALSE

# %%
#true values can convert to 1 and false can convert to 0
sum(is.na(myDF$year))
# Out:
# [1] 1205

# %%
dim(myDF)[1]
# Out:
# [1] 426880

# %%
sum(is.na(myDF$year)) / dim(myDF)[1] #less than 1% of values are NA
# Out:
# [1] 0.002822807

# %%
goodlatitudeDF <- subset(myDF, !is.na(myDF$lat))

# %%
dim(goodlatitudeDF)
# Out:
# [1] 420331     26

# %%
goodlatitudeDF <- subset(myDF, !is.na(lat))

# %%
goodlatitudeDF <- myDF[!is.na(myDF$lat), ] #before comma conditions on rows, after comma conditions on columns

# %%
dim(myDF)
# Out:
# [1] 426880     26

# %%
goodyearsDF <- subset(myDF, !is.na(myDF$year))

# %%
head(goodyearsDF)
# Out:
#    id
# 28 7316814884
# 29 7316814758
# 30 7316814989
# 31 7316743432
# 32 7316356412
# 33 7316343444
#    url
# 28 https://auburn.craigslist.org/ctd/d/auburn-university-2014-gmc-sierra-1500/7316814884.html
# 29 https://auburn.craigslist.org/ctd/d/auburn-university-2010-chevy-chevrolet/7316814758.html
# 30 https://auburn.craigslist.org/ctd/d/auburn-university-2020-chevy-chevrolet/7316814989.html
# 31 https://auburn.craigslist.org/ctd/d/auburn-university-2017-toyota-tundra/7316743432.html
# 32 https://auburn.craigslist.org/cto/d/auburn-university-2013-150/7316356412.html
# 33 https://auburn.craigslist.org/ctd/d/auburn-university-2012-gmc-sierra-2500/7316343444.html
#    region region_url                    price year manufacturer
# 28 auburn https://auburn.craigslist.org 33590 2014 gmc
# 29 auburn https://auburn.craigslist.org 22590 2010 chevrolet
# 30 auburn https://auburn.craigslist.org 39590 2020 chevrolet
# 31 auburn https://auburn.craigslist.org 30990 2017 toyota
# ...

# %%
missingyearsDF <- subset(myDF, is.na(myDF$year))

# %%
head(missingyearsDF)
# Out:
#   id
# 1 7222695916
# 2 7218891961
# 3 7221797935
# 4 7222270760
# 5 7210384030
# 6 7222379453
#   url
# 1 https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html
# 2 https://fayar.craigslist.org/ctd/d/bentonville-2017-hyundai-elantra-se/7218891961.html
# 3 https://keys.craigslist.org/cto/d/summerland-key-2005-excursion/7221797935.html
# 4 https://worcester.craigslist.org/cto/d/west-brookfield-2002-honda-odyssey-ex/7222270760.html
# 5 https://greensboro.craigslist.org/cto/d/trinity-1965-chevrolet-truck/7210384030.html
# 6 https://hudsonvalley.craigslist.org/cto/d/westtown-2007-ford-150/7222379453.html
#   region                 region_url                          price year
# 1 prescott               https://prescott.craigslist.org      6000 NA
# 2 fayetteville           https://fayar.craigslist.org        11900 NA
# 3 florida keys           https://keys.craigslist.org         21000 NA
# 4 worcester / central MA https://worcester.craigslist.org     1500 NA
# ...

# %% [markdown]
# The number of NAs values in myDF is 1205. The percentage of the total number of rows in myDF that represents NA is 0.28%.

# %% [markdown]
# ## Question 3

# %%
aggregate(price ~ type, data = myDF, FUN = mean)
# Out:
#    type        price
# 1              204624.532
# 2  SUV          34434.048
# 3  bus          14105.617
# 4  convertible  19999.774
# 5  coupe        21937.563
# 6  hatchback    14384.513
# 7  mini-van      9234.088
# 8  offroad      15813.094
# 9  other        24743.588
# 10 pickup      144751.640
# 11 sedan        15950.185
# 12 truck        29383.578
# 13 van          17487.597
# 14 wagon        13273.910

# %%
aggregate(price ~ year, data = myDF, FUN = mean)
# Out:
#     year price
# 1   1900    3694.167
# 2   1901    1699.667
# 3   1902 1666666.000
# 4   1903       0.000
# 5   1905    3990.000
# 6   1909     750.000
# 7   1910   15000.000
# 8   1913   56000.000
# 9   1915    5000.000
# 10  1916   21000.000
# 11  1918   16000.000
# 12  1920   11450.000
# 13  1921   11200.000
# 14  1922   15500.000
# 15  1923   17129.583
# 16  1924   14022.222
# 17  1925   11501.000
# 18  1926    9224.688
# 19  1927   12898.486
# 20  1928   25617.737
# 21  1929   19229.632
# 22  1930   21120.206
# 23  1931   19156.207
# 24  1932   31598.561
# 25  1933   48430.000
# 26  1934   31880.432
# 27  1935   19576.130
# 28  1936   19804.442
# 29  1937   27870.843
# 30  1938   17876.816
# ... ...  ...
# 85  1993  149826.777
# 86  1994    9007.966
# 87  1995    9023.120
# 88  1996  103956.104
# 89  1997    7643.831
# 90  1998    6833.067
# 91  1999 1615212.390
# 92  2000 1700951.318
# 93  2001    7505.251
# 94  2002    9582.465
# 95  2003   24268.185
# 96  2004    7505.400
# ...

# %%
subset(aggregate(price ~ year, data = myDF, FUN = mean), year>2002)
# Out:
#     year price
# 95  2003   24268.185
# 96  2004    7505.400
# 97  2005    7950.689
# 98  2006  105032.821
# 99  2007  261162.517
# 100 2008   16993.552
# 101 2009    9071.533
# 102 2010   10252.555
# 103 2011   12503.809
# 104 2012   14089.052
# 105 2013   14748.418
# 106 2014   17144.156
# 107 2015   23408.126
# 108 2016   21495.990
# 109 2017   23970.339
# 110 2018   26368.606
# 111 2019   32975.532
# 112 2020   91897.715
# 113 2021 1338055.311
# 114 2022   27367.053

# %%
table(myDF$year)
# Out:
#  1900  1901  1902  1903  1905  1909  1910  1913  1915  1916  1918  1920  1921
#    12     3     1    12     1     1     2     2     1     2     1     2     2
#  1922  1923  1924  1925  1926  1927  1928  1929  1930  1931  1932  1933  1934
#     3    36     9     8    16    37    38    57    68    58    57    25    44
#  1935  1936  1937  1938  1939  1940  1941  1942  1943  1944  1945  1946  1947
#    23    43    70    38    54    81    67    15     1     3     2    58    71
#  1948  1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
#   100    89   106    98   110   105   100   226   160   174    73    93   120
#  1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  1973
#    82   138   234   270   365   424   357   425   409   345   312   409   334
#  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  1986
#   280   204   242   273   345   387   272   214   217   257   387   469   523
# ...

# %%
which.max(table(myDF$year))
# Out:
# 2017
#  109

# %%
length(table(myDF$year))
# Out:
# [1] 114

# %%
table(myDF$year)[which.max(table(myDF$year))]
# Out:
#  2017
# 36420

# %% [markdown]
# The year where vehicles appear most frequently in our data is 2017 and it's 36420 cars.

# %% [markdown]
# ## Question 4

# %%
head(myDF$region_url )
# Out:
# [1] "https://prescott.craigslist.org"     "https://fayar.craigslist.org"
# [3] "https://keys.craigslist.org"         "https://worcester.craigslist.org"
# [5] "https://greensboro.craigslist.org"   "https://hudsonvalley.craigslist.org"

# %%
tail(sort(table(myDF$region_url )), n = 1)
# Out:
# https://spokane.craigslist.org
#                           2988

# %%
head(myDF$state)
# Out:
# [1] "az" "ar" "fl" "ma" "nc" "ny"

# %%
tail(sort(table(myDF$state)), n = 3)
# Out:
#    tx    fl    ca
# 22945 28511 50614

# %% [markdown]
# The region_url that is the most popular is Spokane on Craigslist with 2988 vehicles.
#
# The three most popular states are Texas, Florida, and California.

# %% [markdown]
# ## Question 5

# %%
myyears <- subset(aggregate(price ~ year, data = myDF, FUN = mean), year>2002)$year

# %%
myprices <- subset(aggregate(price ~ year, data = myDF, FUN = mean), year>2002)$price

# %%
plot(myyears, myprice)
# Out:
# plot without title

# %%
plot(myyears[myprices<500000], myprices[myprices<500000]) 

#ommitted car that are much larger in price as those values were not feasible
# Out:
# plot without title

# %%
plot(myyears[myprices<500000], myprices[myprices<500000], type = "o")

#ommitted car that are much larger in price as those values were not feasible
# Out:
# plot without title

# %%
plot(myyears[myprices<500000], myprices[myprices<500000], type = "h")

#ommitted car that are much larger in price as those values were not feasible
# Out:
# plot without title

# %% [markdown]
# I plotted the data in a histogram, line chart, and scatter plot.
#
# Within the given data of the average price of vehicles by year, I do some trends within the data. First, using the scatterplot, I can clearly see outlier values around $100,000-$200,000, as those might have been years with an overall higher market in car sales due to the economy. However, it is more likely that thoes values are extraneous values with few dealers selling cars of high value. In addition, leaving aside the extraneous data within the dataset, it is apparent that the data is slightly left-skewed, as over time from the past 20 years we see that the prices of cars have been slowly increasing due to more demand for cars over the years. Other than that, with this data present here, it showcases that these car prices are slightly increasing because of technological advancements in the industry and how new cars with that new technology are now starting at a significantly higher price compared to new cars 20 years ago.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
